# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import pandas as pd
import joblib

data = pd.read_csv('C:/Users/RAJ/Desktop/PY/real-estate-predictor/data/new_housing.csv')

x = data[['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income']]
y = data['median_house_value']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = RandomForestRegressor()

model.fit(x_train, y_train)

prediction = model.predict(x_test)

mse = mean_squared_error(y_test, prediction)
print(f"mean squared error : {mse}")

joblib.dump(model, 'C:/Users/RAJ/Desktop/PY/real-estate-predictor/models/house_model1.pkl')

print("Model saved successfully")
# Out:
# mean squared error : 4025735197.027956
# Model saved successfully

# %%
import joblib
import pandas as pd

# 1. Load your saved model
# (Make sure 'model.pkl' is the name of the file you saved)
model = joblib.load('C:/Users/RAJ/Desktop/PY/real-estate-predictor/models/house_model.pkl') 

# 2. Create some dummy data to test
# IMPORTANT: These columns must match EXACTLY what you used for training!
# (Replace these values with real numbers from your dataset structure)
input_data = pd.DataFrame({
    'longitude': [-122.23],       # Example: San Francisco Bay area
    'latitude': [37.88],
    'housing_median_age': [41.0],
    'total_rooms': [880.0],
    'total_bedrooms': [129.0],
    'population': [322.0],
    'households': [126.0],
    'median_income': [8.3252]     # Remember: 8.3 means $83k/year in this dataset
})

# 3. Ask the model to predict
prediction = model.predict(input_data)

print(f" The model predicts the price is: ${prediction[0]}")
# Out:
#  The model predicts the price is: $396256.8256939524
